# %% [markdown]
# ## 강의 소개와 계획
# ---
#
# 코로나 바이러스로 인해 2020년 1학기 강의에 여러 가지 어려움이 생기고 있습니다.
# 통계 데이터베이스를 수강 신청한 학생들은 아래 강의에 대한 소개와 계획을 참고하여 **계속 수강**, **수강 변경** 등을 신중하게 결정하시기 바랍니다.
#
# 1. 강의에 필요한 모든 자료는 [여기](https://github.com/joongyang/Lecture-Materials-for-SQLite)에 있습니다. 강의에 사용할 교재와 실습에 사용할 예제 데이터베이스입니다.
#
# 3. 실습에 사용할 DBMS는 모바일용으로 널리 사용하는 sqlite입니다.
#
# 2. 첫 2주는 비대면 강의이기 때문에 아래에 지정한 날짜에 지정한 부분을 공부하여야 합니다. 그리고 공부한 내용을 요약하여 그날 제출하여야 출석을 인정합니다. 제출은 메일로 하며 보낼 메일 주소는 `joongyang.park@gmail.com`입니다.
#
# 3. 비대면 강의 일정
#
#  * 3월 16일(월) why_statistician_should_study_database 공부한다. sqlite_tutorial.pdf의 2장을 읽고 sqlite을 설치한다. 설치 방법을 정리하여 메일로 제출한다.
#
#   * 3월 18일(수) sqlite_tutorial.pdf의 3장을 읽고 sqlite 명령 이해하고 실행하기, sqlite 명령과 그 기능을 정리한 내용을 메일에 첨부하여 제출한다.
#
#  * 3월 23일(월) sql_tutorial.pdf의 2장을 읽고 DB, DBMS, RDBMS에 대해 공부하고 요약한다. 요약한 내용을 메일로 제출한다.
#
#  * 3월 25일(수) sql_tutorial.pdf의 1장을 읽고 SQL에 대해 공부하고 요약한 것을 메일로 제출한다.
#
# 4. 평소 평가 시험을 3번 실시하였으나, 이번 학기는 2번의 시험을 실시하기로 한다. 각 시험의 비중은 40%이며, 출석 10%, 비대면 강의 기간 중 제출하는 과제는 10%입니다.
